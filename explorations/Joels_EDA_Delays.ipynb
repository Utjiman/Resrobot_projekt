# %%
from pprint import pprint
from backend.connect_to_api import ResRobot

# Skapar en instans av ResRobot
resrobot = ResRobot()

# %%
# Hämta departureBoard-data
departure_data = resrobot.timetable_departure(location_id=740000002)

# %%
import pandas as pd
# Extrahera relevant data för avgångar
departures = []
for dep in departure_data["Departure"]:
    product = dep["Product"][0]
    departures.append(
        {
            "TransportName": product["name"],
            "Line": product["line"],
            "Operator": product["operator"],
            "StopID": dep["stopid"],
            "Time": dep["time"],
        }
    )

df_departures = pd.DataFrame(departures)
print(df_departures)
# Out:
#                TransportName   Line    Operator  \
# 0       Länstrafik - Buss X4     X4  Västtrafik
# 1      Länstrafik - Buss SNU    SNU  Västtrafik
# 2       Länstrafik - Buss X1     X1  Västtrafik
# 3       Länstrafik - Buss 17     17  Västtrafik
# 4      Länstrafik - Buss 510    510  Västtrafik
# ..                       ...    ...         ...
# 243   Länstrafik - Buss TEXP   TEXP  Västtrafik
# 244  Länstrafik - Buss SVART  SVART  Västtrafik
# 245    Länstrafik - Buss SNU    SNU  Västtrafik
# 246     Länstrafik - Buss X1     X1  Västtrafik
# 247   Länstrafik - Spårväg 6      6  Västtrafik
#
#                                                 StopID      Time
# 0    A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  15:56:00
# 1    A=1@O=Göteborg Nils Ericsonterminal@X=11971852...  15:56:00
# 2    A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  15:56:00
# 3    A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  15:57:00
# 4    A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  15:57:00
# ..                                                 ...       ...
# 243  A=1@O=Göteborg Nils Ericsonterminal@X=11971852...  16:55:00
# 244  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  16:55:00
# 245  A=1@O=Göteborg Nils Ericsonterminal@X=11971852...  16:56:00
# 246  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  16:56:00
# 247  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  16:56:00
#
# [248 rows x 5 columns]

# %%
# Hämta arrivalBoard-data
arrival_data = resrobot.timetable_arrival(location_id=740000002)

# %%
# Utforska första Arrival-objektet
pprint(arrival_data["Arrival"][0])
# Out:
# {'JourneyDetailRef': {'ref': '1|304|0|1|21012025'},
#  'JourneyStatus': 'P',
#  'Notes': {'Note': [{'key': 'EG',
#                      'routeIdxFrom': 0,
#                      'routeIdxTo': 9,
#                      'txtN': 'Lag 2015:953 tillämpas',
#                      'type': 'A',
#                      'value': 'Lag 2015:953 tillämpas'}]},
#  'Product': [{'admin': '279___',
#               'catCode': '7',
#               'catIn': 'BLT',
#               'catOut': 'BLT',
#               'catOutL': 'Länstrafik - Buss',
#               'catOutS': 'BLT',
#               'cls': '128',
#               'displayNumber': 'X4',
#               'icon': {'res': 'prod_gen'},
#               'internalName': 'Länstrafik - Buss X4',
#               'line': 'X4',
#               'lineId': '1279520500001',
#               'matchId': 'X4;5205;211',
#               'name': 'Länstrafik - Buss X4',
#               'num': 'X4',
#               'operator': 'Västtrafik',
#               'operatorCode': '279',
#               'operatorInfo': {'id': '279',
#                                'name': 'Västtrafik',
#                                'nameL': 'Västtrafik',
#                                'nameN': '279',
#                                'nameS': '279'},
#               'routeIdxFrom': 8,
#               'routeIdxTo': 9}],
#  'ProductAtStop': {'admin': '279___',
#                    'catCode': '7',
#                    'catIn': 'BLT',
#                    'catOut': 'BLT',
#                    'catOutL': 'Länstrafik - Buss',
#                    'catOutS': 'BLT',
#                    'cls': '128',
#                    'displayNumber': 'X4',
#                    'icon': {'res': 'prod_gen'},
#                    'internalName': 'Länstrafik - Buss X4',
#                    'line': 'X4',
#                    'lineId': '1279520500001',
#                    'matchId': 'X4;5205;211',
#                    'name': 'Länstrafik - Buss X4',
#                    'num': 'X4',
#                    'operator': 'Västtrafik',
#                    'operatorCode': '279',
#                    'operatorInfo': {'id': '279',
#                                     'name': 'Västtrafik',
#                                     'nameL': 'Västtrafik',
#                                     'nameN': '279',
#                                     'nameS': '279'}},
#  'date': '2025-01-21',
#  'lat': 57.70832,
#  'lon': 11.977317,
#  'name': 'Länstrafik - Buss X4',
#  'origin': 'Kungälv resecentrum',
#  'reachable': True,
#  'stop': 'Göteborg Polhemsplatsen',
#  'stopExtId': '740059478',
#  'stopid': 'A=1@O=Göteborg '
#            'Polhemsplatsen@X=11977317@Y=57708320@U=1@L=740059478@',
#  'time': '15:56:00',
#  'type': 'ST'}

# %%
# tar utdata för ankomster
arrivals = []

for arr in arrival_data["Arrival"]:
    product = arr["Product"][0]
    arrivals.append(
        {
            "TransportName": product["name"],
            "Line": product["line"],
            "Operator": product["operator"],
            "StopID": arr["stopid"],
            "Time": arr["time"],
        }
    )

# %%
# Skapa en DataFrame för ankomster
df_arrivals = pd.DataFrame(arrivals)

# %%
print(df_arrivals)
# Out:
#                TransportName   Line    Operator  \
# 0       Länstrafik - Buss X4     X4  Västtrafik
# 1       Länstrafik - Buss X1     X1  Västtrafik
# 2       Länstrafik - Buss 59     59  Västtrafik
# 3       Länstrafik - Buss 17     17  Västtrafik
# 4      Länstrafik - Buss 510    510  Västtrafik
# ..                       ...    ...         ...
# 235     Länstrafik - Buss X1     X1  Västtrafik
# 236    Länstrafik - Tåg 3663   3663  Västtrafik
# 237  Länstrafik - Buss SVART  SVART  Västtrafik
# 238     Länstrafik - Buss X1     X1  Västtrafik
# 239   Länstrafik - Spårväg 6      6  Västtrafik
#
#                                                 StopID      Time
# 0    A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  15:56:00
# 1    A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  15:56:00
# 2    A=1@O=Göteborg Nils Ericsonterminal@X=11971852...  15:57:00
# 3    A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  15:57:00
# 4    A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  15:57:00
# ..                                                 ...       ...
# 235  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  16:55:00
# 236  A=1@O=Göteborg Centralstation@X=11973479@Y=577...  16:55:00
# 237  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  16:55:00
# 238  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  16:56:00
# 239  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  16:56:00
#
# [240 rows x 5 columns]

# %%
# Hämta Trip-data med passlist för mellanliggande stopp
trip_data = resrobot.trips(origin_id=740000002, destination_id=740000001)

# Utforska första resan
pprint(trip_data["Trip"][0])
# Out:
# {'Destination': {'date': '2025-01-21',
#                  'extId': '740000001',
#                  'id': 'A=1@O=Stockholm '
#                        'Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#                  'lat': 59.330136,
#                  'lon': 18.058151,
#                  'minimumChangeDuration': 'PT20M',
#                  'name': 'Stockholm Centralstation',
#                  'prognosisType': 'PROGNOSED',
#                  'routeIdx': 18,
#                  'time': '20:44:00',
#                  'type': 'ST'},
#  'LegList': {'Leg': [{'Destination': {'date': '2025-01-21',
#                                       'extId': '740000001',
#                                       'id': 'A=1@O=Stockholm '
#                                             'Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#                                       'lat': 59.330136,
#                                       'lon': 18.058151,
#                                       'minimumChangeDuration': 'PT20M',
#                                       'name': 'Stockholm Centralstation',
#                                       'prognosisType': 'PROGNOSED',
#                                       'routeIdx': 18,
#                                       'time': '20:44:00',
#                                       'type': 'ST'},
#                       'JourneyDetail': {'dayOfOperation': '2025-01-21',
#                                         'ref': '1|28688|0|1|21012025'},
#                       'JourneyDetailRef': {'ref': '1|28688|0|1|21012025'},
#                       'JourneyStatus': 'P',
#                       'Notes': {'Note': [{'key': 'AB',
#                                           'routeIdxFrom': 0,
#                                           'routeIdxTo': 5,
#                                           'txtN': '2 kl har ej reservering',
#                                           'type': 'A',
#                                           'value': '2 kl har ej reservering'},
#                                          {'key': 'AB',
#                                           'routeIdxFrom': 8,
#                                           'routeIdxTo': 11,
#                                           'txtN': '2 kl har ej reservering',
#                                           'type': 'A',
#                                           'value': '2 kl har ej reservering'},
#                                          {'key': 'AB',
#                                           'routeIdxFrom': 13,
#                                           'routeIdxTo': 18,
#                                           'txtN': '2 kl har ej reservering',
#                                           'type': 'A',
#                                           'value': '2 kl har ej reservering'},
#                                          {'key': 'AF',
#                                           'routeIdxFrom': 0,
#                                           'routeIdxTo': 18,
#                                           'txtN': 'Obligatorisk platsbokning',
#                                           'type': 'A',
#                                           'value': 'Obligatorisk platsbokning'},
#                                          {'key': 'AN',
#                                           'routeIdxFrom': 0,
#                                           'routeIdxTo': 18,
#                                           'txtN': 'Rullstolslyft',
#                                           'type': 'A',
#                                           'value': 'Rullstolslyft'},
#                                          {'key': 'AW',
#                                           'routeIdxFrom': 0,
#                                           'routeIdxTo': 18,
#                                           'txtN': 'WiFi',
#                                           'type': 'A',
#                                           'value': 'WiFi'},
#                                          {'key': 'EJ',
#                                           'routeIdxFrom': 0,
#                                           'routeIdxTo': 18,
#                                           'txtN': 'EU förordning 2021/782',
#                                           'type': 'A',
#                                           'value': 'EU förordning 2021/782'},
#                                          {'key': 'SI',
#                                           'routeIdxFrom': 0,
#                                           'routeIdxTo': 18,
#                                           'txtN': 'Servering finns ej',
#                                           'type': 'A',
#                                           'value': 'Servering finns ej'}]},
#                       'Origin': {'date': '2025-01-21',
#                                  'extId': '740000002',
#                                  'id': 'A=1@O=Göteborg '
#                                        'Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#                                  'lat': 57.708895,
#                                  'lon': 11.973479,
#                                  'minimumChangeDuration': 'PT15M',
#                                  'name': 'Göteborg Centralstation',
#                                  'prognosisType': 'PROGNOSED',
#                                  'routeIdx': 0,
#                                  'time': '15:59:00',
#                                  'type': 'ST'},
#                       'Product': [{'admin': '074___',
#                                    'catCode': '2',
#                                    'catIn': 'JRE',
#                                    'catOut': 'JRE',
#                                    'catOutL': 'Regional Tåg',
#                                    'catOutS': 'JRE',
#                                    'cls': '4',
#                                    'displayNumber': '184',
#                                    'icon': {'res': 'prod_gen'},
#                                    'internalName': 'Regional Tåg 184',
#                                    'line': '184',
#                                    'lineId': '1074018400001',
#                                    'matchId': '184;184;37372',
#                                    'name': 'Regional Tåg 184',
#                                    'num': '184',
#                                    'operator': 'SJ',
#                                    'operatorCode': '74',
#                                    'operatorInfo': {'id': '74',
#                                                     'name': 'SJ',
#                                                     'nameL': 'SJ',
#                                                     'nameN': '74',
#                                                     'nameS': '74'},
#                                    'routeIdxFrom': 0,
#                                    'routeIdxTo': 18}],
#                       'Stops': {'Stop': [{'depDate': '2025-01-21',
#                                           'depDir': 'Stockholm Centralstation',
#                                           'depPrognosisType': 'PROGNOSED',
#                                           'depTime': '15:59:00',
#                                           'extId': '740000002',
#                                           'id': 'A=1@O=Göteborg '
#                                                 'Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#                                           'lat': 57.708895,
#                                           'lon': 11.973479,
#                                           'minimumChangeDuration': 'PT15M',
#                                           'name': 'Göteborg Centralstation',
#                                           'routeIdx': 0},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '16:28:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '16:28:00',
#                                           'extId': '740000018',
#                                           'id': 'A=1@O=Alingsås '
#                                                 'station@X=12532491@Y=57926857@U=1@L=740000018@',
#                                           'lat': 57.926857,
#                                           'lon': 12.532491,
#                                           'minimumChangeDuration': 'PT7M',
#                                           'name': 'Alingsås station',
#                                           'routeIdx': 1},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '16:40:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '16:40:00',
#                                           'extId': '740000569',
#                                           'id': 'A=1@O=Vårgårda '
#                                                 'station@X=12810285@Y=58031204@U=1@L=740000569@',
#                                           'lat': 58.031204,
#                                           'lon': 12.810285,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Vårgårda station',
#                                           'routeIdx': 2},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '16:47:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '16:48:00',
#                                           'extId': '740000040',
#                                           'id': 'A=1@O=Herrljunga '
#                                                 'station@X=13021279@Y=58079188@U=1@L=740000040@',
#                                           'lat': 58.079188,
#                                           'lon': 13.021279,
#                                           'minimumChangeDuration': 'PT8M',
#                                           'name': 'Herrljunga station',
#                                           'routeIdx': 3},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '17:03:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '17:04:00',
#                                           'extId': '740000060',
#                                           'id': 'A=1@O=Falköping '
#                                                 'Centralstation@X=13553791@Y=58176101@U=1@L=740000060@',
#                                           'lat': 58.176101,
#                                           'lon': 13.553791,
#                                           'minimumChangeDuration': 'PT8M',
#                                           'name': 'Falköping Centralstation',
#                                           'routeIdx': 4},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '17:18:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '17:19:00',
#                                           'extId': '740000008',
#                                           'id': 'A=1@O=Skövde '
#                                                 'Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#                                           'lat': 58.390898,
#                                           'lon': 13.853195,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Skövde Centralstation',
#                                           'routeIdx': 5},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '17:35:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '17:35:00',
#                                           'extId': '740000183',
#                                           'id': 'A=1@O=Töreboda '
#                                                 'station@X=14128391@Y=58706024@U=1@L=740000183@',
#                                           'lat': 58.706024,
#                                           'lon': 14.128391,
#                                           'minimumChangeDuration': 'PT8M',
#                                           'name': 'Töreboda station',
#                                           'routeIdx': 6},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '17:59:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '18:08:00',
#                                           'extId': '740000194',
#                                           'id': 'A=1@O=Laxå '
#                                                 'station@X=14616658@Y=58989391@U=1@L=740000194@',
#                                           'lat': 58.989391,
#                                           'lon': 14.616658,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Laxå station',
#                                           'routeIdx': 7},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '18:25:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '18:28:00',
#                                           'extId': '740000077',
#                                           'id': 'A=1@O=Hallsberg '
#                                                 'station@X=15110391@Y=59066698@U=1@L=740000077@',
#                                           'lat': 59.066698,
#                                           'lon': 15.110391,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Hallsberg station',
#                                           'routeIdx': 8},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '18:35:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '18:35:00',
#                                           'extId': '740000192',
#                                           'id': 'A=1@O=Kumla '
#                                                 'station@X=15140280@Y=59126377@U=1@L=740000192@',
#                                           'lat': 59.126377,
#                                           'lon': 15.14028,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Kumla station',
#                                           'routeIdx': 9},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '18:46:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '18:46:00',
#                                           'extId': '740000361',
#                                           'id': 'A=1@O=Örebro Södra '
#                                                 'station@X=15202332@Y=59269989@U=1@L=740000361@',
#                                           'lat': 59.269989,
#                                           'lon': 15.202332,
#                                           'minimumChangeDuration': 'PT1H30M',
#                                           'name': 'Örebro Södra station',
#                                           'routeIdx': 10},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '18:49:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '18:56:00',
#                                           'extId': '740000133',
#                                           'id': 'A=1@O=Örebro '
#                                                 'Centralstation@X=15211348@Y=59278942@U=1@L=740000133@',
#                                           'lat': 59.278942,
#                                           'lon': 15.211348,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Örebro Centralstation',
#                                           'routeIdx': 11},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '19:18:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '19:18:00',
#                                           'extId': '740000262',
#                                           'id': 'A=1@O=Arboga '
#                                                 'station@X=15841061@Y=59397105@U=1@L=740000262@',
#                                           'lat': 59.397105,
#                                           'lon': 15.841061,
#                                           'minimumChangeDuration': 'PT5M',
#                                           'name': 'Arboga station',
#                                           'routeIdx': 12},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '19:29:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '19:29:00',
#                                           'extId': '740000167',
#                                           'id': 'A=1@O=Köping '
#                                                 'station@X=16004215@Y=59506675@U=1@L=740000167@',
#                                           'lat': 59.506675,
#                                           'lon': 16.004215,
#                                           'minimumChangeDuration': 'PT5M',
#                                           'name': 'Köping station',
#                                           'routeIdx': 13},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '19:46:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '19:48:00',
#                                           'extId': '740000099',
#                                           'id': 'A=1@O=Västerås '
#                                                 'Centralstation@X=16551712@Y=59607705@U=1@L=740000099@',
#                                           'lat': 59.607705,
#                                           'lon': 16.551712,
#                                           'minimumChangeDuration': 'PT8M',
#                                           'name': 'Västerås Centralstation',
#                                           'routeIdx': 14},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '20:03:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '20:03:00',
#                                           'extId': '740000072',
#                                           'id': 'A=1@O=Enköping '
#                                                 'station@X=17086741@Y=59644327@U=1@L=740000072@',
#                                           'lat': 59.644327,
#                                           'lon': 17.086741,
#                                           'minimumChangeDuration': 'PT8M',
#                                           'name': 'Enköping station',
#                                           'routeIdx': 15},
#                                          {'arrDate': '2025-01-21',
#                                           'arrTime': '20:15:00',
#                                           'depDate': '2025-01-21',
#                                           'depTime': '20:15:00',
#                                           'extId': '740000660',
#                                           'id': 'A=1@O=Bålsta station (Håbo '
#                                                 'kn)@X=17532813@Y=59568754@U=1@L=740000660@',
#                                           'lat': 59.568754,
#                                           'lon': 17.532813,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Bålsta station (Håbo kn)',
#                                           'routeIdx': 16},
#                                          {'Notes': {'Note': [{'key': 'text.realtime.stop.entry.disabled',
#                                                               'txtN': 'Stannar '
#                                                                       'endast '
#                                                                       'för '
#                                                                       'avstigande',
#                                                               'type': 'R',
#                                                               'value': 'Stannar '
#                                                                        'endast '
#                                                                        'för '
#                                                                        'avstigande'}]},
#                                           'arrDate': '2025-01-21',
#                                           'arrTime': '20:36:00',
#                                           'boarding': False,
#                                           'extId': '740000773',
#                                           'id': 'A=1@O=Sundbyberg '
#                                                 'station@X=17970938@Y=59361032@U=1@L=740000773@',
#                                           'lat': 59.361032,
#                                           'lon': 17.970938,
#                                           'minimumChangeDuration': 'PT10M',
#                                           'name': 'Sundbyberg station',
#                                           'routeIdx': 17},
#                                          {'arrDate': '2025-01-21',
#                                           'arrPrognosisType': 'PROGNOSED',
#                                           'arrTime': '20:44:00',
#                                           'extId': '740000001',
#                                           'id': 'A=1@O=Stockholm '
#                                                 'Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#                                           'lat': 59.330136,
#                                           'lon': 18.058151,
#                                           'minimumChangeDuration': 'PT20M',
#                                           'name': 'Stockholm Centralstation',
#                                           'routeIdx': 18}]},
#                       'category': 'JRE',
#                       'direction': 'Stockholm Centralstation',
#                       'directionFlag': '1',
#                       'duration': 'PT4H45M',
#                       'id': '0',
#                       'idx': 0,
#                       'name': 'Regional Tåg 184',
#                       'number': '184',
#                       'reachable': True,
#                       'type': 'JNY',
#                       'waitingState': 'UNDEF'}]},
#  'Origin': {'date': '2025-01-21',
#             'extId': '740000002',
#             'id': 'A=1@O=Göteborg '
#                   'Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#             'lat': 57.708895,
#             'lon': 11.973479,
#             'minimumChangeDuration': 'PT15M',
#             'name': 'Göteborg Centralstation',
#             'prognosisType': 'PROGNOSED',
#             'routeIdx': 0,
#             'time': '15:59:00',
#             'type': 'ST'},
#  'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#                   'planningPeriodEnd': '2025-06-15',
#                   'sDaysB': '00013E7CF9F3E7CF9F3E7CF9F3838E9F3E7CE1E200',
#                   'sDaysI': '21. jan t o m 9. jun 2025 mån - fre; utom 17. t o '
#                             'm 21. apr 2025, 25. apr, 1., 29., 30. maj, 6. jun',
#                   'sDaysR': 'inte varje dag'}],
#  'TripStatus': {'convenient': True, 'economic': True, 'hintCode': 0},
#  'calculation': 'INITIAL',
#  'checksum': 'a13e6124_3',
#  'ctxRecon': '¶HKI¶T$A=1@O=Göteborg '
#              'Centralstation@L=740000002@a=128@$A=1@O=Stockholm '
#              'Centralstation@L=740000001@a=128@$202501211559$202501212044$JRE  '
#              '184$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#  'duration': 'PT4H45M',
#  'idx': 0,
#  'rtDuration': 'PT4H45M',
#  'tripId': 'C-0'}

# %%
# departureboard för en station

station_id = 740000002

departure_json = resrobot.timetable_departure(location_id=station_id)

pprint(departure_json)
# Out:
# {'Departure': [{'JourneyDetailRef': {'ref': '1|304|0|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 9,
#                                     'routeIdxTo': 27,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'X4',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss X4',
#                              'line': 'X4',
#                              'lineId': '1279520500001',
#                              'matchId': 'X4;5205;211',
#                              'name': 'Länstrafik - Buss X4',
#                              'num': 'X4',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 9,
#                              'routeIdxTo': 27}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'X4',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss X4',
#                                   'line': 'X4',
#                                   'lineId': '1279520500001',
#                                   'matchId': 'X4;5205;211',
#                                   'name': 'Länstrafik - Buss X4',
#                                   'num': 'X4',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Höga hallar (Härryda kn)',
#                 'directionFlag': '1',
#                 'lat': 57.70832,
#                 'lon': 11.977317,
#                 'name': 'Länstrafik - Buss X4',
#                 'reachable': True,
#                 'stop': 'Göteborg Polhemsplatsen',
#                 'stopExtId': '740059478',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Polhemsplatsen@X=11977317@Y=57708320@U=1@L=740059478@',
#                 'time': '15:56:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|32155|8|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 15,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'SNU',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss SNU',
#                              'line': 'SNU',
#                              'lineId': '1279621400001',
#                              'matchId': 'SNU;6214;96',
#                              'name': 'Länstrafik - Buss SNU',
#                              'num': 'SNU',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 0,
#                              'routeIdxTo': 15}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'SNU',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss SNU',
#                                   'line': 'SNU',
#                                   'lineId': '1279621400001',
#                                   'matchId': 'SNU;6214;96',
#                                   'name': 'Länstrafik - Buss SNU',
#                                   'num': 'SNU',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Stenungsund station',
#                 'directionFlag': '2',
#                 'lat': 57.710271,
#                 'lon': 11.971852,
#                 'name': 'Länstrafik - Buss SNU',
#                 'reachable': True,
#                 'stop': 'Göteborg Nils Ericsonterminal',
#                 'stopExtId': '740020483',
#                 'stopid': 'A=1@O=Göteborg Nils '
#                           'Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#                 'time': '15:56:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|100041|4|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 24,
#                                     'routeIdxTo': 26,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'X1',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss X1',
#                              'line': 'X1',
#                              'lineId': '1279521200001',
#                              'matchId': 'X1;5212;128',
#                              'name': 'Länstrafik - Buss X1',
#                              'num': 'X1',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 24,
#                              'routeIdxTo': 26}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'X1',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss X1',
#                                   'line': 'X1',
#                                   'lineId': '1279521200001',
#                                   'matchId': 'X1;5212;128',
#                                   'name': 'Länstrafik - Buss X1',
#                                   'num': 'X1',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Partille centrum',
#                 'directionFlag': '2',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss X1',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '15:56:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|68166|3|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 13,
#                                     'routeIdxTo': 27,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': '17',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss 17',
#                              'line': '17',
#                              'lineId': '1279501700001',
#                              'matchId': '17;5017;159',
#                              'name': 'Länstrafik - Buss 17',
#                              'num': '17',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 13,
#                              'routeIdxTo': 27}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': '17',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss 17',
#                                   'line': '17',
#                                   'lineId': '1279501700001',
#                                   'matchId': '17;5017;159',
#                                   'name': 'Länstrafik - Buss 17',
#                                   'num': '17',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Göteborg Östra sjukhuset',
#                 'directionFlag': '1',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss 17',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '15:57:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|135652|3|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 1,
#                                     'routeIdxTo': 14,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': '510',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss 510',
#                              'line': '510',
#                              'lineId': '1279551000001',
#                              'matchId': '510;5510;74',
#                              'name': 'Länstrafik - Buss 510',
#                              'num': '510',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 1,
#                              'routeIdxTo': 14}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': '510',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss 510',
#                                   'line': '510',
#                                   'lineId': '1279551000001',
#                                   'matchId': '510;5510;74',
#                                   'name': 'Länstrafik - Buss 510',
#                                   'num': '510',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Partille centrum',
#                 'directionFlag': '2',
#                 'lat': 57.70832,
#                 'lon': 11.977317,
#                 'name': 'Länstrafik - Buss 510',
#                 'reachable': True,
#                 'stop': 'Göteborg Polhemsplatsen',
#                 'stopExtId': '740059478',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Polhemsplatsen@X=11977317@Y=57708320@U=1@L=740059478@',
#                 'time': '15:57:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|541|1|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 18,
#                                     'routeIdxTo': 27,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'X4',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss X4',
#                              'line': 'X4',
#                              'lineId': '1279520500001',
#                              'matchId': 'X4;5205;214',
#                              'name': 'Länstrafik - Buss X4',
#                              'num': 'X4',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 18,
#                              'routeIdxTo': 27}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'X4',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss X4',
#                                   'line': 'X4',
#                                   'lineId': '1279520500001',
#                                   'matchId': 'X4;5205;214',
#                                   'name': 'Länstrafik - Buss X4',
#                                   'num': 'X4',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Kungälv resecentrum',
#                 'directionFlag': '2',
#                 'lat': 57.70832,
#                 'lon': 11.977317,
#                 'name': 'Länstrafik - Buss X4',
#                 'reachable': True,
#                 'stop': 'Göteborg Polhemsplatsen',
#                 'stopExtId': '740059478',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Polhemsplatsen@X=11977317@Y=57708320@U=1@L=740059478@',
#                 'time': '15:58:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|68251|3|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 2,
#                                     'routeIdxTo': 15,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': '17',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss 17',
#                              'line': '17',
#                              'lineId': '1279501700001',
#                              'matchId': '17;5017;166',
#                              'name': 'Länstrafik - Buss 17',
#                              'num': '17',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 2,
#                              'routeIdxTo': 15}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': '17',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss 17',
#                                   'line': '17',
#                                   'lineId': '1279501700001',
#                                   'matchId': '17;5017;166',
#                                   'name': 'Länstrafik - Buss 17',
#                                   'num': '17',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Hinnebäcksgatan (Göteborg kn)',
#                 'directionFlag': '2',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss 17',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '15:58:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|135579|1|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 13,
#                                     'routeIdxTo': 14,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': '510',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss 510',
#                              'line': '510',
#                              'lineId': '1279551000001',
#                              'matchId': '510;5510;67',
#                              'name': 'Länstrafik - Buss 510',
#                              'num': '510',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 13,
#                              'routeIdxTo': 14}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': '510',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss 510',
#                                   'line': '510',
#                                   'lineId': '1279551000001',
#                                   'matchId': '510;5510;67',
#                                   'name': 'Länstrafik - Buss 510',
#                                   'num': '510',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Göteborg Heden',
#                 'directionFlag': '1',
#                 'lat': 57.70832,
#                 'lon': 11.977317,
#                 'name': 'Länstrafik - Buss 510',
#                 'reachable': True,
#                 'stop': 'Göteborg Polhemsplatsen',
#                 'stopExtId': '740059478',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Polhemsplatsen@X=11977317@Y=57708320@U=1@L=740059478@',
#                 'time': '15:58:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|383|0|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 8,
#                                     'routeIdxTo': 21,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'X4',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss X4',
#                              'line': 'X4',
#                              'lineId': '1279520500001',
#                              'matchId': 'X4;5205;213',
#                              'name': 'Länstrafik - Buss X4',
#                              'num': 'X4',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 8,
#                              'routeIdxTo': 21}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'X4',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss X4',
#                                   'line': 'X4',
#                                   'lineId': '1279520500001',
#                                   'matchId': 'X4;5205;213',
#                                   'name': 'Länstrafik - Buss X4',
#                                   'num': 'X4',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Mölnlycke station (Härryda kn)',
#                 'directionFlag': '1',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss X4',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '15:59:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|541|1|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 19,
#                                     'routeIdxTo': 27,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'X4',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss X4',
#                              'line': 'X4',
#                              'lineId': '1279520500001',
#                              'matchId': 'X4;5205;214',
#                              'name': 'Länstrafik - Buss X4',
#                              'num': 'X4',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 19,
#                              'routeIdxTo': 27}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'X4',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss X4',
#                                   'line': 'X4',
#                                   'lineId': '1279520500001',
#                                   'matchId': 'X4;5205;214',
#                                   'name': 'Länstrafik - Buss X4',
#                                   'num': 'X4',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Kungälv resecentrum',
#                 'directionFlag': '2',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss X4',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '15:59:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|21991|7|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 9,
#                                     'routeIdxTo': 18,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': '16',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss 16',
#                              'line': '16',
#                              'lineId': '1279501600001',
#                              'matchId': '16;5016;171',
#                              'name': 'Länstrafik - Buss 16',
#                              'num': '16',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 9,
#                              'routeIdxTo': 18}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': '16',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss 16',
#                                   'line': '16',
#                                   'lineId': '1279501600001',
#                                   'matchId': '16;5016;171',
#                                   'name': 'Länstrafik - Buss 16',
#                                   'num': '16',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Göteborg Marklandsgatan',
#                 'directionFlag': '1',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss 16',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '15:59:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|22089|5|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 9,
#                                     'routeIdxTo': 18,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': '16',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss 16',
#                              'line': '16',
#                              'lineId': '1279501600001',
#                              'matchId': '16;5016;172',
#                              'name': 'Länstrafik - Buss 16',
#                              'num': '16',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 9,
#                              'routeIdxTo': 18}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': '16',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss 16',
#                                   'line': '16',
#                                   'lineId': '1279501600001',
#                                   'matchId': '16;5016;172',
#                                   'name': 'Länstrafik - Buss 16',
#                                   'num': '16',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Bockkranen (Göteborg kn)',
#                 'directionFlag': '2',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss 16',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '15:59:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|28688|0|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'AB',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 5,
#                                     'txtN': '2 kl har ej reservering',
#                                     'type': 'A',
#                                     'value': '2 kl har ej reservering'},
#                                    {'key': 'AF',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 18,
#                                     'txtN': 'Obligatorisk platsbokning',
#                                     'type': 'A',
#                                     'value': 'Obligatorisk platsbokning'},
#                                    {'key': 'AN',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 18,
#                                     'txtN': 'Rullstolslyft',
#                                     'type': 'A',
#                                     'value': 'Rullstolslyft'},
#                                    {'key': 'AW',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 18,
#                                     'txtN': 'WiFi',
#                                     'type': 'A',
#                                     'value': 'WiFi'},
#                                    {'key': 'EJ',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 18,
#                                     'txtN': 'EU förordning 2021/782',
#                                     'type': 'A',
#                                     'value': 'EU förordning 2021/782'},
#                                    {'key': 'SI',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 18,
#                                     'txtN': 'Servering finns ej',
#                                     'type': 'A',
#                                     'value': 'Servering finns ej'}]},
#                 'Product': [{'admin': '074___',
#                              'catCode': '2',
#                              'catIn': 'JRE',
#                              'catOut': 'JRE',
#                              'catOutL': 'Regional Tåg',
#                              'catOutS': 'JRE',
#                              'cls': '4',
#                              'displayNumber': '184',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Regional Tåg 184',
#                              'line': '184',
#                              'lineId': '1074018400001',
#                              'matchId': '184;184;37372',
#                              'name': 'Regional Tåg 184',
#                              'num': '184',
#                              'operator': 'SJ',
#                              'operatorCode': '74',
#                              'operatorInfo': {'id': '74',
#                                               'name': 'SJ',
#                                               'nameL': 'SJ',
#                                               'nameN': '74',
#                                               'nameS': '74'},
#                              'routeIdxFrom': 0,
#                              'routeIdxTo': 18}],
#                 'ProductAtStop': {'admin': '074___',
#                                   'catCode': '2',
#                                   'catIn': 'JRE',
#                                   'catOut': 'JRE',
#                                   'catOutL': 'Regional Tåg',
#                                   'catOutS': 'JRE',
#                                   'cls': '4',
#                                   'displayNumber': '184',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Regional Tåg 184',
#                                   'line': '184',
#                                   'lineId': '1074018400001',
#                                   'matchId': '184;184;37372',
#                                   'name': 'Regional Tåg 184',
#                                   'num': '184',
#                                   'operator': 'SJ',
#                                   'operatorCode': '74',
#                                   'operatorInfo': {'id': '74',
# ...
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 18,
#                                     'routeIdxTo': 29,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'SVART',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss SVART',
#                              'line': 'SVART',
#                              'lineId': '1279521100001',
#                              'matchId': 'SVART;5211;123',
#                              'name': 'Länstrafik - Buss SVART',
#                              'num': 'SVART',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 18,
#                              'routeIdxTo': 29}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'SVART',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss SVART',
#                                   'line': 'SVART',
#                                   'lineId': '1279521100001',
#                                   'matchId': 'SVART;5211;123',
#                                   'name': 'Länstrafik - Buss SVART',
#                                   'num': 'SVART',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Sävedalen Ljungkullen (Partille kn)',
#                 'directionFlag': '1',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss SVART',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '16:55:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|32157|4|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 0,
#                                     'routeIdxTo': 15,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'SNU',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss SNU',
#                              'line': 'SNU',
#                              'lineId': '1279621400001',
#                              'matchId': 'SNU;6214;112',
#                              'name': 'Länstrafik - Buss SNU',
#                              'num': 'SNU',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 0,
#                              'routeIdxTo': 15}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'SNU',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss SNU',
#                                   'line': 'SNU',
#                                   'lineId': '1279621400001',
#                                   'matchId': 'SNU;6214;112',
#                                   'name': 'Länstrafik - Buss SNU',
#                                   'num': 'SNU',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Stenungsund station',
#                 'directionFlag': '2',
#                 'lat': 57.710271,
#                 'lon': 11.971852,
#                 'name': 'Länstrafik - Buss SNU',
#                 'reachable': True,
#                 'stop': 'Göteborg Nils Ericsonterminal',
#                 'stopExtId': '740020483',
#                 'stopid': 'A=1@O=Göteborg Nils '
#                           'Ericsonterminal@X=11971852@Y=57710271@U=1@L=740020483@',
#                 'time': '16:56:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|100042|1|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 24,
#                                     'routeIdxTo': 26,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '7',
#                              'catIn': 'BLT',
#                              'catOut': 'BLT',
#                              'catOutL': 'Länstrafik - Buss',
#                              'catOutS': 'BLT',
#                              'cls': '128',
#                              'displayNumber': 'X1',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Buss X1',
#                              'line': 'X1',
#                              'lineId': '1279521200001',
#                              'matchId': 'X1;5212;140',
#                              'name': 'Länstrafik - Buss X1',
#                              'num': 'X1',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 24,
#                              'routeIdxTo': 26}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '7',
#                                   'catIn': 'BLT',
#                                   'catOut': 'BLT',
#                                   'catOutL': 'Länstrafik - Buss',
#                                   'catOutS': 'BLT',
#                                   'cls': '128',
#                                   'displayNumber': 'X1',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Buss X1',
#                                   'line': 'X1',
#                                   'lineId': '1279521200001',
#                                   'matchId': 'X1;5212;140',
#                                   'name': 'Länstrafik - Buss X1',
#                                   'num': 'X1',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Partille centrum',
#                 'directionFlag': '2',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Buss X1',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '16:56:00',
#                 'type': 'ST'},
#                {'JourneyDetailRef': {'ref': '1|155787|0|1|21012025'},
#                 'JourneyStatus': 'P',
#                 'Notes': {'Note': [{'key': 'EG',
#                                     'routeIdxFrom': 15,
#                                     'routeIdxTo': 45,
#                                     'txtN': 'Lag 2015:953 tillämpas',
#                                     'type': 'A',
#                                     'value': 'Lag 2015:953 tillämpas'}]},
#                 'Product': [{'admin': '279___',
#                              'catCode': '6',
#                              'catIn': 'SLT',
#                              'catOut': 'SLT',
#                              'catOutL': 'Länstrafik - Spårväg',
#                              'catOutS': 'SLT',
#                              'cls': '64',
#                              'displayNumber': '6',
#                              'icon': {'res': 'prod_gen'},
#                              'internalName': 'Länstrafik - Spårväg 6',
#                              'line': '6',
#                              'lineId': '1279500600001',
#                              'matchId': '6;5006;5797',
#                              'name': 'Länstrafik - Spårväg 6',
#                              'num': '6',
#                              'operator': 'Västtrafik',
#                              'operatorCode': '279',
#                              'operatorInfo': {'id': '279',
#                                               'name': 'Västtrafik',
#                                               'nameL': 'Västtrafik',
#                                               'nameN': '279',
#                                               'nameS': '279'},
#                              'routeIdxFrom': 15,
#                              'routeIdxTo': 45}],
#                 'ProductAtStop': {'admin': '279___',
#                                   'catCode': '6',
#                                   'catIn': 'SLT',
#                                   'catOut': 'SLT',
#                                   'catOutL': 'Länstrafik - Spårväg',
#                                   'catOutS': 'SLT',
#                                   'cls': '64',
#                                   'displayNumber': '6',
#                                   'icon': {'res': 'prod_gen'},
#                                   'internalName': 'Länstrafik - Spårväg 6',
#                                   'line': '6',
#                                   'lineId': '1279500600001',
#                                   'matchId': '6;5006;5797',
#                                   'name': 'Länstrafik - Spårväg 6',
#                                   'num': '6',
#                                   'operator': 'Västtrafik',
#                                   'operatorCode': '279',
#                                   'operatorInfo': {'id': '279',
#                                                    'name': 'Västtrafik',
#                                                    'nameL': 'Västtrafik',
#                                                    'nameN': '279',
#                                                    'nameS': '279'}},
#                 'date': '2025-01-21',
#                 'direction': 'Kortedala Aprilgatan (Göteborg kn)',
#                 'directionFlag': '1',
#                 'lat': 57.709246,
#                 'lon': 11.970791,
#                 'name': 'Länstrafik - Spårväg 6',
#                 'reachable': True,
#                 'stop': 'Göteborg Nordstan',
#                 'stopExtId': '740015585',
#                 'stopid': 'A=1@O=Göteborg '
#                           'Nordstan@X=11970791@Y=57709246@U=1@L=740015585@',
#                 'time': '16:56:00',
#                 'type': 'ST'}],
#  'TechnicalMessages': {'TechnicalMessage': [{'key': 'requestTime',
#                                              'value': '2025-01-21 15:56:47'},
#                                             {'key': 'backendInfo',
#                                              'value': 'ttp=16439#16603 '
#                                                       'plancode0=0pi2w '
#                                                       'planid=1737434182 '
#                                                       'planid0=1737434182 '
#                                                       'planid_adr=1479298166 '
#                                                       'plancode_adr=q0r10 '
#                                                       'srvv=5.45.SAMTRAFIKEN.15.0.1 '
#                                                       '(customer/hcusamtrafiken/release/2023.10.0) '
#                                                       '[2023-10-19] '
#                                                       'tlibv=TRFVER: '
#                                                       'rel/pproxy/4.00.0 '
#                                                       '2022-10-24 18:24:51 '
#                                                       '+0200 '
#                                                       'Relay_EnrichmentProxy '
#                                                       'v1 jno=1'}]},
#  'dialectVersion': '2.45',
#  'planRtTs': '1970-01-01T01:00:00.000+01:00',
#  'requestId': 'kj6iznmqkagvh4wg',
#  'serverVersion': '2.45.1'}

# %%
df_dep = pd.DataFrame(departure_json.get("Departure", []))

print(df_dep.columns.tolist())
df_dep.head(10)
# Out:
# ['JourneyDetailRef', 'JourneyStatus', 'ProductAtStop', 'Product', 'Notes', 'name', 'type', 'stop', 'stopid', 'stopExtId', 'lon', 'lat', 'time', 'date', 'reachable', 'direction', 'directionFlag', 'rtPlatform', 'prognosisType', 'rtTime', 'rtDate', 'rtTrack']
#                    JourneyDetailRef JourneyStatus  \
# 0     {'ref': '1|304|0|1|21012025'}             P
# 1   {'ref': '1|32155|8|1|21012025'}             P
# 2  {'ref': '1|100041|4|1|21012025'}             P
# 3   {'ref': '1|68166|3|1|21012025'}             P
# 4  {'ref': '1|135652|3|1|21012025'}             P
# 5     {'ref': '1|541|1|1|21012025'}             P
# 6   {'ref': '1|68251|3|1|21012025'}             P
# 7  {'ref': '1|135579|1|1|21012025'}             P
# 8     {'ref': '1|383|0|1|21012025'}             P
# 9     {'ref': '1|541|1|1|21012025'}             P
#
#                                        ProductAtStop  \
# 0  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 1  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 2  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 3  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 4  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 5  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 6  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 7  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 8  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 9  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 3  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 4  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 5  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 6  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 7  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 8  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 9  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Notes                   name  \
# 0  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...   Länstrafik - Buss X4
# 1  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Buss SNU
# 2  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...   Länstrafik - Buss X1
# 3  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...   Länstrafik - Buss 17
# 4  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Buss 510
# 5  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...   Länstrafik - Buss X4
# 6  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...   Länstrafik - Buss 17
# 7  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Buss 510
# 8  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...   Länstrafik - Buss X4
# 9  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...   Länstrafik - Buss X4
#
#   type                           stop  \
# 0   ST        Göteborg Polhemsplatsen
# 1   ST  Göteborg Nils Ericsonterminal
# 2   ST              Göteborg Nordstan
# 3   ST              Göteborg Nordstan
# 4   ST        Göteborg Polhemsplatsen
# 5   ST        Göteborg Polhemsplatsen
# 6   ST              Göteborg Nordstan
# 7   ST        Göteborg Polhemsplatsen
# 8   ST              Göteborg Nordstan
# 9   ST              Göteborg Nordstan
#
#                                               stopid  stopExtId  ...  \
# 0  A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  740059478  ...
# 1  A=1@O=Göteborg Nils Ericsonterminal@X=11971852...  740020483  ...
# 2  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  ...
# 3  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  ...
# 4  A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  740059478  ...
# 5  A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  740059478  ...
# 6  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  ...
# 7  A=1@O=Göteborg Polhemsplatsen@X=11977317@Y=577...  740059478  ...
# 8  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  ...
# 9  A=1@O=Göteborg Nordstan@X=11970791@Y=57709246@...  740015585  ...
#
#        time        date reachable                       direction  \
# 0  15:56:00  2025-01-21      True        Höga hallar (Härryda kn)
# 1  15:56:00  2025-01-21      True             Stenungsund station
# 2  15:56:00  2025-01-21      True                Partille centrum
# 3  15:57:00  2025-01-21      True        Göteborg Östra sjukhuset
# 4  15:57:00  2025-01-21      True                Partille centrum
# 5  15:58:00  2025-01-21      True             Kungälv resecentrum
# 6  15:58:00  2025-01-21      True   Hinnebäcksgatan (Göteborg kn)
# 7  15:58:00  2025-01-21      True                  Göteborg Heden
# 8  15:59:00  2025-01-21      True  Mölnlycke station (Härryda kn)
# 9  15:59:00  2025-01-21      True             Kungälv resecentrum
#
#    directionFlag rtPlatform prognosisType rtTime rtDate rtTrack
# 0              1        NaN           NaN    NaN    NaN     NaN
# 1              2        NaN           NaN    NaN    NaN     NaN
# 2              2        NaN           NaN    NaN    NaN     NaN
# 3              1        NaN           NaN    NaN    NaN     NaN
# 4              2        NaN           NaN    NaN    NaN     NaN
# 5              2        NaN           NaN    NaN    NaN     NaN
# 6              2        NaN           NaN    NaN    NaN     NaN
# 7              1        NaN           NaN    NaN    NaN     NaN
# 8              1        NaN           NaN    NaN    NaN     NaN
# 9              2        NaN           NaN    NaN    NaN     NaN
#
# [10 rows x 22 columns]

# %%
# Utforskar: rtTime, rtDate, rtTrack, rtDepTrack

realtime_cols = ["rtTime", "rtDate", "rtTrack", "rtDepTrack"]
for c in realtime_cols:
    if c in df_dep.columns:
        print(f"\n=== EDA för kolumn '{c}' ===")
        print(" - Antal icke-NaN:", df_dep[c].notna().sum())
        print(" - Unika värden:", df_dep[c].unique()[:15], "... (visar max 15 unika)")
        print(" - value_counts:", df_dep[c].value_counts(dropna=False).head(10))
    else:
        print(f"\nKolumn '{c}' saknas i df_dep")

# Räknar hur många avgångar som har rtTrack
if "rtTrack" in df_dep.columns:
    num_with_rttrack = df_dep["rtTrack"].notna().sum()
    print(f"\nAntal avgångar med 'rtTrack' ifyllt: {num_with_rttrack}")
else:
    print("\n'rtTrack' saknas.")
# Out:
# === EDA för kolumn 'rtTime' ===
#  - Antal icke-NaN: 27
#  - Unika värden: [nan '15:59:00' '16:00:00' '16:03:00' '16:04:00' '16:05:00' '16:06:00'
#  '16:10:00' '16:13:00' '16:15:00' '16:18:00' '16:19:00' '16:20:00'
#  '16:25:00' '16:30:00'] ... (visar max 15 unika)
#  - value_counts: rtTime
# NaN         221
# 16:00:00      2
# 16:35:00      2
# 16:15:00      2
# 16:10:00      2
# 16:45:00      2
# 16:40:00      2
# 16:30:00      2
# 15:59:00      1
# 16:04:00      1
# Name: count, dtype: int64
#
# === EDA för kolumn 'rtDate' ===
#  - Antal icke-NaN: 27
#  - Unika värden: [nan '2025-01-21'] ... (visar max 15 unika)
#  - value_counts: rtDate
# NaN           221
# 2025-01-21     27
# Name: count, dtype: int64
#
# === EDA för kolumn 'rtTrack' ===
#  - Antal icke-NaN: 27
#  - Unika värden: [nan '4' '9' '15' '6' '11' '10' '2' '14' '8' '5' '1' '16' '12' '3'] ... (visar max 15 unika)
#  - value_counts: rtTrack
# NaN    221
# 10       4
# 15       3
# 4        3
# 16       3
# 9        2
# 14       2
# 8        2
# 2        1
# 11       1
# Name: count, dtype: int64
#
# Kolumn 'rtDepTrack' saknas i df_dep
#
# Antal avgångar med 'rtTrack' ifyllt: 27

# %%
# Om 'rtTime' saknas använder vi 'time'.

def get_departure_time(row):
    if pd.notna(row.get("rtTime")) and row["rtTime"]:
        return row["rtTime"]
    else:
        return row["time"]

df_dep["usedTime"] = df_dep.apply(get_departure_time, axis=1)

# Kolla några rader
df_dep[["time","rtTime","usedTime"]].head(10)
# Out:
#        time rtTime  usedTime
# 0  15:56:00    NaN  15:56:00
# 1  15:56:00    NaN  15:56:00
# 2  15:56:00    NaN  15:56:00
# 3  15:57:00    NaN  15:57:00
# 4  15:57:00    NaN  15:57:00
# 5  15:58:00    NaN  15:58:00
# 6  15:58:00    NaN  15:58:00
# 7  15:58:00    NaN  15:58:00
# 8  15:59:00    NaN  15:59:00
# 9  15:59:00    NaN  15:59:00

# %%
# Räkna hur många rader = hur många avgångar/ankomster
num_departures = len(df_departures)
num_arrivals = len(df_arrivals)

print(f"Number of departures at station {station_id}: {num_departures}")
print(f"Number of arrivals at station {station_id}: {num_arrivals}")
# Out:
# Number of departures at station 740000002: 248
# Number of arrivals at station 740000002: 240

# %%
import matplotlib.pyplot as plt

df_counts = pd.DataFrame({
    "Type": ["Departures", "Arrivals"],
    "Count": [num_departures, num_arrivals]
})

# Rita ett stapeldiagram
df_counts.plot(kind="bar", x="Type", y="Count", legend=False, color=["skyblue","orange"], figsize=(6,4))
plt.title(f"Departures vs. Arrivals at Station {station_id}")
plt.xlabel("")
plt.ylabel("Number of records")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()



labels = ["Departures", "Arrivals"]
counts = [num_departures, num_arrivals]

# Välj några färger
colors = ["#1f77b4", "#ff7f0e"]  # Ex: blå och orange

# %%
df_counts = pd.DataFrame({
    "Type": ["Departures", "Arrivals"],
    "Count": [num_departures, num_arrivals]
})

plt.figure(figsize=(6,4))
# .plot(kind="barh") → horisontella staplar
df_counts.plot(kind="barh", x="Type", y="Count", legend=False, 
               color=["#6CABDD","#F8C471"], figsize=(6,4))

plt.title(f"Departures vs. Arrivals at Station {station_id}")
plt.xlabel("Count")
plt.ylabel("")
plt.tight_layout()
plt.show()
