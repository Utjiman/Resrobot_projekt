# %% [markdown]
# # Explorations

# %%
from backend.connect_to_api import ResRobot

resrobot = ResRobot()

resrobot.access_id_from_location("Umeå")
# Out:
# Name                                               extId
# UMEÅ                                               740098065
# Umeå Centralstation                                740000190
# Umeå Busstation                                    740020461
# Umeå Östra station                                 740001581
# Umeå Vasaplan                                      740020116
# Umeå Airport                                       740025159
# Umeå Ålidhem centrum                               740023156
# Umeå Ålidhöjd                                      740045439
# Umeå Älvans väg                                    740045410
# Umeå Alviksgränd                                   740045280

# %%
resrobot.access_id_from_location("Göteborg")
# Out:
# Name                                               extId
# GÖTEBORG                                           740098001
# Göteborg Centralstation                            740000002
# Göteborg Sävenäs lokstation                        740016365
# GÖTEBORG GAMLESTADEN                               740098526
# Göteborg Korsvägen                                 740015578
# Göteborg Kungsportsplatsen                         740016358
# Göteborg Stenpiren                                 740072430
# Göteborg Eketrägatan                               740025624
# Göteborg Vårväderstorget                           740025707
# Göteborg Axel Dahlströms torg                      740025608

# %%
umea_id = 740000190
gothenburg_id = 740000002

trips = resrobot.trips(umea_id, gothenburg_id)

len(trips["Trip"])
# Out:
# 5

# %%
trips["Trip"][2]["LegList"]
# Out:
# {'Leg': [{'Origin': {'name': 'Umeå Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#     'extId': '740000190',
#     'lon': 20.26681,
#     'lat': 63.830064,
#     'routeIdx': 7,
#     'prognosisType': 'PROGNOSED',
#     'time': '21:16:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT10M'},
#    'Destination': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 19,
#     'prognosisType': 'PROGNOSED',
#     'time': '07:01:00',
#     'date': '2025-01-13',
#     'minimumChangeDuration': 'PT20M'},
#    'Notes': {'Note': [{'value': 'Endast 2 klass',
#       'key': 'AA',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Endast 2 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Sov- och liggvagn',
#       'key': 'SL',
#       'type': 'A',
#       'routeIdxFrom': 7,
#       'routeIdxTo': 19,
#       'txtN': 'Sov- och liggvagn'}]},
#    'JourneyDetailRef': {'ref': '1|37717|0|1|12012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Nattåg 91',
#      'internalName': 'Nattåg 91',
#      'displayNumber': '91',
#      'num': '91',
#      'line': '91',
#      'lineId': '1074009100003',
#      'catOut': 'JNT',
#      'catIn': 'JNT',
#      'catCode': '2',
#      'cls': '4',
#      'catOutS': 'JNT',
#      'catOutL': 'Nattåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 7,
#      'routeIdxTo': 19,
#      'matchId': '91;91;23363'}],
#    'Stops': {'Stop': [{'name': 'Umeå Centralstation',
#       'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#       'extId': '740000190',
#       'routeIdx': 7,
#       'lon': 20.26681,
#       'lat': 63.830064,
#       'depTime': '21:16:00',
#       'depDate': '2025-01-12',
#       'depDir': 'Stockholm Centralstation',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Umeå Östra station',
#       'id': 'A=1@O=Umeå Östra station@X=20293454@Y=63817659@U=1@L=740001581@',
#       'extId': '740001581',
#       'routeIdx': 8,
#       'lon': 20.293454,
#       'lat': 63.817659,
#       'depTime': '21:23:00',
#       'depDate': '2025-01-12',
#       'arrTime': '21:22:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Nordmaling Resecentrum/Station (Nordmaling-AC kn)',
#       'id': 'A=1@O=Nordmaling Resecentrum/Station (Nordmaling-AC kn)@X=19486285@Y=63578303@U=1@L=740001583@',
#       'extId': '740001583',
#       'routeIdx': 9,
#       'lon': 19.486285,
#       'lat': 63.578303,
#       'depTime': '21:56:00',
#       'depDate': '2025-01-12',
#       'arrTime': '21:56:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT5M'},
#      {'name': 'Örnsköldsvik Centralstation',
#       'id': 'A=1@O=Örnsköldsvik Centralstation@X=18704305@Y=63289282@U=1@L=740001570@',
#       'extId': '740001570',
#       'routeIdx': 10,
#       'lon': 18.704305,
#       'lat': 63.289282,
#       'depTime': '22:35:00',
#       'depDate': '2025-01-12',
#       'arrTime': '22:35:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Kramfors station',
#       'id': 'A=1@O=Kramfors station@X=17778182@Y=62929111@U=1@L=740000220@',
#       'extId': '740000220',
#       'routeIdx': 11,
#       'lon': 17.778182,
#       'lat': 62.929111,
#       'depTime': '23:28:00',
#       'depDate': '2025-01-12',
#       'arrTime': '23:28:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Härnösand station',
#       'id': 'A=1@O=Härnösand station@X=17928635@Y=62635182@U=1@L=740000253@',
#       'extId': '740000253',
#       'routeIdx': 12,
#       'lon': 17.928635,
#       'lat': 62.635182,
#       'depTime': '00:07:00',
#       'depDate': '2025-01-13',
#       'arrTime': '00:07:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Sundsvall Centralstation',
#       'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#       'extId': '740000130',
#       'routeIdx': 13,
#       'lon': 17.315633,
#       'lat': 62.386873,
#       'depTime': '01:17:00',
#       'depDate': '2025-01-13',
#       'arrTime': '01:02:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Hudiksvall station',
#       'id': 'A=1@O=Hudiksvall station@X=17109034@Y=61724494@U=1@L=740000187@',
#       'extId': '740000187',
#       'routeIdx': 14,
#       'lon': 17.109034,
#       'lat': 61.724494,
#       'depTime': '03:00:00',
#       'depDate': '2025-01-13',
#       'arrTime': '02:56:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Söderhamn station',
#       'id': 'A=1@O=Söderhamn station@X=17035682@Y=61299600@U=1@L=740000154@',
#       'extId': '740000154',
#       'routeIdx': 15,
#       'lon': 17.035682,
#       'lat': 61.2996,
#       'depTime': '03:35:00',
#       'depDate': '2025-01-13',
#       'arrTime': '03:35:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Gävle Centralstation',
#       'id': 'A=1@O=Gävle Centralstation@X=17151221@Y=60676118@U=1@L=740000210@',
#       'extId': '740000210',
#       'routeIdx': 16,
#       'lon': 17.151221,
#       'lat': 60.676118,
#       'depTime': '04:51:00',
#       'depDate': '2025-01-13',
#       'arrTime': '04:31:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Uppsala Centralstation',
#       'id': 'A=1@O=Uppsala Centralstation@X=17646086@Y=59858531@U=1@L=740000005@',
#       'extId': '740000005',
#       'routeIdx': 17,
#       'lon': 17.646086,
#       'lat': 59.858531,
#       'arrTime': '05:53:00',
#       'arrDate': '2025-01-13',
#       'boarding': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Arlanda Centralstation (Sigtuna kn)',
#       'id': 'A=1@O=Arlanda Centralstation (Sigtuna kn)@X=17929201@Y=59649469@U=1@L=740000556@',
#       'extId': '740000556',
#       'routeIdx': 18,
#       'lon': 17.929201,
#       'lat': 59.649469,
#       'arrTime': '06:35:00',
#       'arrDate': '2025-01-13',
#       'boarding': False,
#       'minimumChangeDuration': 'PT2H'},
#      {'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 19,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '07:01:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT20M'}]},
#    'JourneyDetail': {'ref': '1|37717|0|1|12012025',
#     'dayOfOperation': '2025-01-12'},
#    'id': '0',
#    'idx': 0,
#    'name': 'Nattåg 91',
#    'number': '91',
#    'category': 'JNT',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Stockholm Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT9H45M',
#    'minimumChangeDuration': 'PT20M'},
#   {'Origin': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '08:12:00',
#     'date': '2025-01-13',
#     'minimumChangeDuration': 'PT20M'},
#    'Destination': {'name': 'Göteborg Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#     'extId': '740000002',
#     'lon': 11.973479,
#     'lat': 57.708895,
#     'routeIdx': 3,
#     'prognosisType': 'PROGNOSED',
#     'time': '11:41:00',
#     'date': '2025-01-13',
#     'minimumChangeDuration': 'PT15M'},
#    'Notes': {'Note': [{'value': 'X2000',
#       'key': 'VX',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'X2000'},
#      {'value': 'Mat 1 klass',
#       'key': 'A1',
#       'type': 'A',
#       'routeIdxFrom': 1,
#       'routeIdxTo': 3,
#       'txtN': 'Mat 1 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'WiFi'},
#      {'value': '2 klass lugn',
#       'key': 'BL',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '2 klass lugn'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Frukost 1 klass',
#       'key': 'SF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Frukost 1 klass'},
#      {'value': 'Maträtt',
#       'key': 'SM',
#       'type': 'A',
#       'routeIdxFrom': 1,
#       'routeIdxTo': 3,
#       'txtN': 'Maträtt'},
#      {'value': '1 klass med extra komfort',
#       'key': 'SU',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '1 klass med extra komfort'},
#      {'value': 'Kaffebuffé 1 klass',
#       'key': 'SZ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Kaffebuffé 1 klass'}]},
#    'JourneyDetailRef': {'ref': '1|28577|0|1|13012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Snabbtåg 425',
#      'internalName': 'Snabbtåg 425',
#      'displayNumber': '425',
#      'num': '425',
#      'line': '425',
#      'lineId': '1074042500001',
#      'catOut': 'JST',
#      'catIn': 'JST',
#      'catCode': '1',
#      'cls': '2',
#      'catOutS': 'JST',
#      'catOutL': 'Snabbtåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 3,
#      'matchId': '425;425;59149'}],
#    'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 0,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '08:12:00',
#       'depDate': '2025-01-13',
#       'depDir': 'Göteborg Centralstation',
#       'minimumChangeDuration': 'PT20M'},
#      {'name': 'Katrineholm Centralstation',
#       'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#       'extId': '740000166',
#       'routeIdx': 1,
#       'lon': 16.208324,
#       'lat': 58.996591,
#       'depTime': '09:04:00',
#       'depDate': '2025-01-13',
#       'arrTime': '09:03:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Skövde Centralstation',
#       'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#       'extId': '740000008',
#       'routeIdx': 2,
#       'lon': 13.853195,
#       'lat': 58.390898,
#       'depTime': '10:22:00',
#       'depDate': '2025-01-13',
#       'arrTime': '10:22:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Göteborg Centralstation',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'routeIdx': 3,
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '11:41:00',
#       'arrDate': '2025-01-13',
#       'minimumChangeDuration': 'PT15M'}]},
#    'JourneyDetail': {'ref': '1|28577|0|1|13012025',
#     'dayOfOperation': '2025-01-13'},
#    'id': '1',
#    'idx': 1,
#    'name': 'Snabbtåg 425',
#    'number': '425',
#    'category': 'JST',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Göteborg Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT3H29M'}]}

# %%
import pandas as pd 

# pd.DataFrame(trips["Trip"])
legs = []

for trip in trips.get("Trip"):
    legs.append(trip.get("LegList").get("Leg"))

# Umeå -> Stockholm
legs[0][0]["Origin"], legs[0][0]["Destination"]
# Out:
# ({'name': 'Umeå Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#   'extId': '740000190',
#   'lon': 20.26681,
#   'lat': 63.830064,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '17:37:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Sundsvall Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#   'extId': '740000130',
#   'lon': 17.315633,
#   'lat': 62.386873,
#   'routeIdx': 11,
#   'prognosisType': 'PROGNOSED',
#   'time': '20:41:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'})

# %%
# Stockholm -> Göteborg
legs[0][1]["Origin"], legs[0][1]["Destination"]
# Out:
# ({'name': 'Sundsvall Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#   'extId': '740000130',
#   'lon': 17.315633,
#   'lat': 62.386873,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '20:53:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Gävle Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Gävle Centralstation@X=17151221@Y=60676118@U=1@L=740000210@',
#   'extId': '740000210',
#   'lon': 17.151221,
#   'lat': 60.676118,
#   'routeIdx': 3,
#   'prognosisType': 'PROGNOSED',
#   'time': '23:10:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'})

# %%
next_available_trip = legs[0]
df = pd.DataFrame(next_available_trip)
df
# Out:
#                                               Origin  \
# 0  {'name': 'Umeå Centralstation', 'type': 'ST', ...
# 1  {'name': 'Sundsvall Centralstation', 'type': '...
# 2  {'name': 'Gävle Centralstation', 'type': 'ST',...
#
#                                          Destination  \
# 0  {'name': 'Sundsvall Centralstation', 'type': '...
# 1  {'name': 'Gävle Centralstation', 'type': 'ST',...
# 2  {'name': 'Göteborg Centralstation', 'type': 'S...
#
#                                                Notes  \
# 0  {'Note': [{'value': 'Endast 2 klass', 'key': '...
# 1  {'Note': [{'value': 'SJ3000', 'key': 'V3', 'ty...
# 2  {'Note': [{'value': 'Endast 2 klass', 'key': '...
#
#                    JourneyDetailRef JourneyStatus  \
# 0   {'ref': '1|60646|0|1|12012025'}             P
# 1   {'ref': '1|57709|0|1|12012025'}             P
# 2  {'ref': '1|130787|0|1|12012025'}             P
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Stops  \
# 0  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1  {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2  {'Stop': [{'name': 'Gävle Centralstation', 'id...
#
#                                        JourneyDetail id  idx  \
# 0  {'ref': '1|60646|0|1|12012025', 'dayOfOperatio...  0    0
# 1  {'ref': '1|57709|0|1|12012025', 'dayOfOperatio...  1    1
# 2  {'ref': '1|130787|0|1|12012025', 'dayOfOperati...  2    2
#
#                 name number category type  reachable waitingState  \
# 0  Regional Tåg 7419   7419      JRE  JNY       True        UNDEF
# 1       Snabbtåg 599    599      JST  JNY       True        UNDEF
# 2          Nattåg 77     77      JNT  JNY       True        UNDEF
#
#                   direction directionFlag duration minimumChangeDuration
# 0  Sundsvall Centralstation             1   PT3H4M                 PT10M
# 1  Stockholm Centralstation             1  PT2H17M                  PT2H
# 2   Göteborg Centralstation             1  PT6H15M                   NaN

# %%
df_trip = df[["name", "Stops"]]
df_trip
# Out:
#                 name                                              Stops
# 0  Regional Tåg 7419  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1       Snabbtåg 599  {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2          Nattåg 77  {'Stop': [{'name': 'Gävle Centralstation', 'id...

# %%
df_trip["Stops"]
# Out:
# 0    {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1    {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2    {'Stop': [{'name': 'Gävle Centralstation', 'id...
# Name: Stops, dtype: object

# %%
all_stops = pd.json_normalize(df["Stops"].dropna(), "Stop")
all_stops.head()
# Out:
#                                                 name  \
# 0                                Umeå Centralstation
# 1                                 Umeå Östra station
# 2            Hörnefors Resecentrum/Station (Umeå kn)
# 3  Nordmaling Resecentrum/Station (Nordmaling-AC kn)
# 4                    Husum station (Örnsköldsvik kn)
#
#                                                   id      extId  routeIdx  \
# 0  A=1@O=Umeå Centralstation@X=20266810@Y=6383006...  740000190         0
# 1  A=1@O=Umeå Östra station@X=20293454@Y=63817659...  740001581         1
# 2  A=1@O=Hörnefors Resecentrum/Station (Umeå kn)@...  740001582         2
# 3  A=1@O=Nordmaling Resecentrum/Station (Nordmali...  740001583         3
# 4  A=1@O=Husum station (Örnsköldsvik kn)@X=191557...  740001584         4
#
#          lon        lat depPrognosisType   depTime     depDate  \
# 0  20.266810  63.830064        PROGNOSED  17:37:00  2025-01-12
# 1  20.293454  63.817659              NaN  17:42:00  2025-01-12
# 2  19.908464  63.632661              NaN  17:56:00  2025-01-12
# 3  19.486285  63.578303              NaN  18:08:00  2025-01-12
# 4  19.155725  63.343909              NaN  18:22:00  2025-01-12
#
#                      depDir minimumChangeDuration alighting  \
# 0  Sundsvall Centralstation                 PT10M       NaN
# 1                       NaN                 PT10M     False
# 2                       NaN                  PT5M       NaN
# 3                       NaN                  PT5M       NaN
# 4                       NaN                 PT10M       NaN
#
#                                           Notes.Note   arrTime     arrDate  \
# 0                                                NaN       NaN         NaN
# 1  [{'value': 'Stannar endast för påstigande', 'k...       NaN         NaN
# 2                                                NaN  17:56:00  2025-01-12
# 3                                                NaN  18:07:00  2025-01-12
# 4                                                NaN  18:22:00  2025-01-12
#
#   boarding arrPrognosisType
# 0      NaN              NaN
# 1      NaN              NaN
# 2      NaN              NaN
# 3      NaN              NaN
# 4      NaN              NaN

# %%
stops = all_stops[["name", "arrTime", "arrDate", "depTime", "depDate", "lon", "lat"]]
stops
# Out:
#                                                  name   arrTime     arrDate  \
# 0                                 Umeå Centralstation       NaN         NaN
# 1                                  Umeå Östra station       NaN         NaN
# 2             Hörnefors Resecentrum/Station (Umeå kn)  17:56:00  2025-01-12
# 3   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  18:07:00  2025-01-12
# 4                     Husum station (Örnsköldsvik kn)  18:22:00  2025-01-12
# 5                          Örnsköldsvik Norra station  18:34:00  2025-01-12
# 6                         Örnsköldsvik Centralstation  18:37:00  2025-01-12
# 7                                    Kramfors station  19:22:00  2025-01-12
# 8                                   Härnösand station  19:47:00  2025-01-12
# 9                                       Timrå station  20:24:00  2025-01-12
# 10                           Sundsvall Västra station  20:37:00  2025-01-12
# 11                           Sundsvall Centralstation  20:41:00  2025-01-12
# 12                           Sundsvall Centralstation       NaN         NaN
# 13                                 Hudiksvall station  21:57:00  2025-01-12
# 14                                  Söderhamn station  22:28:00  2025-01-12
# 15                               Gävle Centralstation  23:10:00  2025-01-12
# 16                               Gävle Centralstation       NaN         NaN
# 17                              Örebro Centralstation  05:29:00  2025-01-13
# 18                                  Hallsberg station  05:53:00  2025-01-13
# 19                              Skövde Centralstation  07:04:00  2025-01-13
# 20                                 Herrljunga station  07:43:00  2025-01-13
# 21                            Göteborg Centralstation  08:41:00  2025-01-13
#
#      depTime     depDate        lon        lat
# 0   17:37:00  2025-01-12  20.266810  63.830064
# 1   17:42:00  2025-01-12  20.293454  63.817659
# 2   17:56:00  2025-01-12  19.908464  63.632661
# 3   18:08:00  2025-01-12  19.486285  63.578303
# 4   18:22:00  2025-01-12  19.155725  63.343909
# 5   18:34:00  2025-01-12  18.716108  63.303035
# 6   18:37:00  2025-01-12  18.704305  63.289282
# 7   19:22:00  2025-01-12  17.778182  62.929111
# 8   19:47:00  2025-01-12  17.928635  62.635182
# 9   20:24:00  2025-01-12  17.330546  62.486392
# 10       NaN         NaN  17.291668  62.389893
# 11       NaN         NaN  17.315633  62.386873
# 12  20:53:00  2025-01-12  17.315633  62.386873
# 13  21:57:00  2025-01-12  17.109034  61.724494
# 14  22:28:00  2025-01-12  17.035682  61.299600
# 15       NaN         NaN  17.151221  60.676118
# 16  02:26:00  2025-01-13  17.151221  60.676118
# 17       NaN         NaN  15.211348  59.278942
# 18       NaN         NaN  15.110391  59.066698
# 19       NaN         NaN  13.853195  58.390898
# 20       NaN         NaN  13.021279  58.079188
# 21       NaN         NaN  11.973479  57.708895

# %%
stops = stops.drop_duplicates(subset="name").reset_index(drop=True)
stops
# Out:
#                                                  name   arrTime     arrDate  \
# 0                                 Umeå Centralstation       NaN         NaN
# 1                                  Umeå Östra station       NaN         NaN
# 2             Hörnefors Resecentrum/Station (Umeå kn)  17:56:00  2025-01-12
# 3   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  18:07:00  2025-01-12
# 4                     Husum station (Örnsköldsvik kn)  18:22:00  2025-01-12
# 5                          Örnsköldsvik Norra station  18:34:00  2025-01-12
# 6                         Örnsköldsvik Centralstation  18:37:00  2025-01-12
# 7                                    Kramfors station  19:22:00  2025-01-12
# 8                                   Härnösand station  19:47:00  2025-01-12
# 9                                       Timrå station  20:24:00  2025-01-12
# 10                           Sundsvall Västra station  20:37:00  2025-01-12
# 11                           Sundsvall Centralstation  20:41:00  2025-01-12
# 12                                 Hudiksvall station  21:57:00  2025-01-12
# 13                                  Söderhamn station  22:28:00  2025-01-12
# 14                               Gävle Centralstation  23:10:00  2025-01-12
# 15                              Örebro Centralstation  05:29:00  2025-01-13
# 16                                  Hallsberg station  05:53:00  2025-01-13
# 17                              Skövde Centralstation  07:04:00  2025-01-13
# 18                                 Herrljunga station  07:43:00  2025-01-13
# 19                            Göteborg Centralstation  08:41:00  2025-01-13
#
#      depTime     depDate        lon        lat
# 0   17:37:00  2025-01-12  20.266810  63.830064
# 1   17:42:00  2025-01-12  20.293454  63.817659
# 2   17:56:00  2025-01-12  19.908464  63.632661
# 3   18:08:00  2025-01-12  19.486285  63.578303
# 4   18:22:00  2025-01-12  19.155725  63.343909
# 5   18:34:00  2025-01-12  18.716108  63.303035
# 6   18:37:00  2025-01-12  18.704305  63.289282
# 7   19:22:00  2025-01-12  17.778182  62.929111
# 8   19:47:00  2025-01-12  17.928635  62.635182
# 9   20:24:00  2025-01-12  17.330546  62.486392
# 10       NaN         NaN  17.291668  62.389893
# 11       NaN         NaN  17.315633  62.386873
# 12  21:57:00  2025-01-12  17.109034  61.724494
# 13  22:28:00  2025-01-12  17.035682  61.299600
# 14       NaN         NaN  17.151221  60.676118
# 15       NaN         NaN  15.211348  59.278942
# 16       NaN         NaN  15.110391  59.066698
# 17       NaN         NaN  13.853195  58.390898
# 18       NaN         NaN  13.021279  58.079188
# 19       NaN         NaN  11.973479  57.708895

# %%
stops["time"] = stops["arrTime"].fillna(stops["depTime"])
stops["date"] = stops["arrDate"].fillna(stops["depDate"])

# %%
import folium

geographical_map = folium.Map(
    location=[stops["lat"].mean(), stops["lon"].mean()], zoom_start=5
)

for _, row in stops.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f"{row['name']}<br>{row['time']}<br>{row['date']}",
    ).add_to(geographical_map)

geographical_map
